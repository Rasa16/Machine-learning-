# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train = pd.read_excel('F:\\study material\\covid 19 dataset\\Train_dataset.xlsx')
train.head(10)
# Out:
#    people_ID        Region  Gender Designation             Name Married  \
# 0          1  Bhubaneshwar  Female         Mrs            mansi     YES
# 1          2  Bhubaneshwar  Female         Mrs        riya masi     YES
# 2          3  Bhubaneshwar  Female         Mrs           sunita      NO
# 3          4  Bhubaneshwar  Female         Mrs   anjali @ babli     YES
# 4          5  Bhubaneshwar  Female         Mrs  champa karketta      NO
# 5          6  Bhubaneshwar  Female         Mrs          sandhya     YES
# 6          7  Bhubaneshwar  Female         Mrs             iqra     YES
# 7          8  Bhubaneshwar  Female         Mrs     renu @ rinki     YES
# 8          9  Bhubaneshwar  Female         Mrs    kalyani patro     YES
# 9         10  Bhubaneshwar  Female         Mrs     gurdeep kaur     YES
#
#    Children     Occupation Mode_transport  cases/1M  ...    HBB d-dimer  \
# 0       1.0         Farmer         Public         2  ...   93.0   233.0
# ...

# %%
test = pd.read_excel('F:\\study material\\covid 19 dataset\\Test_dataset.xlsx')
test.head(10)
# Out:
#    people_ID Region  Gender Designation                Name Married  Children  \
# 0       5942  Delhi  Female         Mrs  smt rekha prajapat     YES         2
# 1      18664  Delhi    Male          Mr              nirmal     YES         2
# 2       5603  Delhi  Female         Mrs               pinky     YES         2
# 3       5649  Delhi  Female         Mrs       pooja @aafrin     YES         2
# 4       5099  Delhi  Female         Mrs              anjali     YES         2
# 5      18749  Delhi    Male          Mr         diwan chand     YES         2
# 6       5228  Delhi  Female         Mrs              sunita     YES         2
# 7       5559  Delhi  Female         Mrs              gaytri     YES         2
# 8       5220  Delhi  Female         Mrs                ritu     YES         2
# 9       5476  Delhi  Female         Mrs              poonam     YES         2
#
#       Occupation Mode_transport  cases/1M  ...  Platelets  HBB  d-dimer  \
# ...

# %%
train['Children'].value_counts().idxmax()
test['Children'].value_counts().idxmax()

train['Children'].fillna('2.0',inplace = True)
test['Children'].fillna('2.0',inplace = True)

# %%
train['Occupation'].value_counts().idxmax()
test['Occupation'].value_counts().idxmax()

train['Occupation'].fillna('Legal',inplace = True)
test['Occupation'].fillna('Legal',inplace = True)


train['Mode_transport'].value_counts().idxmax()
test['Mode_transport'].value_counts().idxmax()

train['Mode_transport'].fillna('Public',inplace = True)
test['Mode_transport'].fillna('Public',inplace = True)

train['cardiological pressure'].fillna('Normal',inplace = True)
test['cardiological pressure'].fillna('Normal',inplace = True)

train['Diuresis'].fillna('276.0',inplace = True)
test['Diuresis'].fillna('276.0',inplace = True)

train['Platelets'].fillna('88.0',inplace = True)
test['Platelets'].fillna('88.0',inplace = True)

train['HBB'].fillna('117.0',inplace = True)
test['HBB'].fillna('117.0',inplace = True)

train['d-dimer'].fillna('276.0',inplace = True)
test['d-dimer'].fillna('276.0',inplace = True)

train['Heart rate'].fillna('75.0',inplace = True)
test['Heart rate'].fillna('75.0',inplace = True)

train['HDL cholesterol'].fillna('53.0',inplace = True)
test['HDL cholesterol'].fillna('53.0',inplace = True)

train['Insurance'].fillna('2600000.0',inplace = True)
test['Insurance'].fillna('2600000.0',inplace = True)

train['FT/month'].fillna('1.0',inplace = True)
test['FT/month'].fillna('1.0',inplace = True)

# %%
train.head()
# Out:
#    people_ID        Region  Gender Designation             Name Married  \
# 0          1  Bhubaneshwar  Female         Mrs            mansi     YES
# 1          2  Bhubaneshwar  Female         Mrs        riya masi     YES
# 2          3  Bhubaneshwar  Female         Mrs           sunita      NO
# 3          4  Bhubaneshwar  Female         Mrs   anjali @ babli     YES
# 4          5  Bhubaneshwar  Female         Mrs  champa karketta      NO
#
#   Children     Occupation Mode_transport  cases/1M  ...  HBB d-dimer  \
# 0        1         Farmer         Public         2  ...   93     233
# 1        2         Farmer           Walk         2  ...   56     328
# 2        1        Cleaner         Public         2  ...  137     213
# 3        1         Driver            Car         2  ...  167     275
# 4        2  Manufacturing            Car         2  ...  153     331
#
#    Heart rate  HDL cholesterol Charlson Index Blood Glucose Insurance  \
# ...

# %%
test.head()
# Out:
#    people_ID Region  Gender Designation                Name Married  Children  \
# 0       5942  Delhi  Female         Mrs  smt rekha prajapat     YES         2
# 1      18664  Delhi    Male          Mr              nirmal     YES         2
# 2       5603  Delhi  Female         Mrs               pinky     YES         2
# 3       5649  Delhi  Female         Mrs       pooja @aafrin     YES         2
# 4       5099  Delhi  Female         Mrs              anjali     YES         2
#
#   Occupation Mode_transport  cases/1M  ...  Platelets  HBB  d-dimer  \
# 0     Driver         Public         4  ...        153  196      240
# 1      Legal           Walk         4  ...         95  138      241
# 2      Sales            Car         4  ...         40  166      236
# 3      Sales            Car         4  ...         78   83      211
# 4   Business            Car         4  ...        109  207      312
#
#    Heart rate HDL cholesterol Charlson Index  Blood Glucose  Insurance  \
# ...

# %%
train.isna().sum()
# Out:
# people_ID                   0
# Region                      0
# Gender                      0
# Designation                 0
# Name                       20
# Married                     0
# Children                    0
# Occupation                  0
# Mode_transport              0
# cases/1M                    0
# Deaths/1M                   0
# comorbidity               226
# Age                         0
# Coma score                  0
# Pulmonary score             0
# cardiological pressure      0
# Diuresis                    0
# Platelets                   0
# HBB                         0
# d-dimer                     0
# Heart rate                  0
# HDL cholesterol             0
# Charlson Index              0
# Blood Glucose               0
# Insurance                   0
# salary                      0
# FT/month                    0
# Infect_Prob                 0
# dtype: int64

# %%
test.isna().sum()
# Out:
# people_ID                  0
# Region                     0
# Gender                     0
# Designation                0
# Name                      32
# Married                    0
# Children                   0
# Occupation                 0
# Mode_transport             0
# cases/1M                   0
# Deaths/1M                  0
# comorbidity                0
# Age                        0
# Coma score                 0
# Pulmonary score            0
# cardiological pressure     0
# Diuresis                   0
# Platelets                  0
# HBB                        0
# d-dimer                    0
# Heart rate                 0
# HDL cholesterol            0
# Charlson Index             0
# Blood Glucose              0
# Insurance                  0
# salary                     0
# FT/month                   0
# dtype: int64

# %%
dummies = pd.get_dummies(train['comorbidity'])
dummies1 = pd.get_dummies(test['comorbidity'])

# %%
train = pd.concat([train,dummies],axis='columns')
test = pd.concat([test,dummies1],axis='columns')

# %%
train.drop('comorbidity',axis='columns',inplace=True)
test.drop('comorbidity',axis='columns',inplace=True)

# %%
train.drop('None',axis='columns',inplace=True)
test.drop('None',axis='columns',inplace=True)

# %%
dummies = pd.get_dummies(train['Mode_transport'])
dummies1 = pd.get_dummies(test['Mode_transport'])

# %%
train = pd.concat([train,dummies],axis='columns')
test = pd.concat([test,dummies1],axis='columns')

# %%
train.drop('Mode_transport',axis='columns',inplace=True)
test.drop('Mode_transport',axis='columns',inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

le_married = LabelEncoder()
le_occupation = LabelEncoder()
le_gender = LabelEncoder()

#train
train['Married_n'] = le_married.fit_transform(train['Married'])
train['Occupation_n'] = le_occupation.fit_transform(train['Occupation'])
train['Gender_n'] = le_gender.fit_transform(train['Gender'])

#test
test['Married_n'] = le_married.fit_transform(test['Married'])
test['Occupation_n'] = le_occupation.fit_transform(test['Occupation'])
test['Gender_n'] = le_gender.fit_transform(test['Gender'])

# %%
train.drop('Married',axis='columns',inplace=True)
test.drop('Married',axis='columns',inplace=True)

train.drop('Occupation',axis='columns',inplace=True)
test.drop('Occupation',axis='columns',inplace=True)

train.drop('Gender',axis='columns',inplace=True)
test.drop('Gender',axis='columns',inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
scaler = MinMaxScaler()

#train
scaler.fit(train[['Insurance']])
train['Insurance'] = scaler.transform(train[['Insurance']])

scaler.fit(train[['salary']])
train['salary'] = scaler.transform(train[['salary']])

#test
scaler.fit(test[['Insurance']])
test['Insurance'] = scaler.transform(test[['Insurance']])

scaler.fit(test[['salary']])
test['salary'] = scaler.transform(test[['salary']])

# %%
train.replace({'<100':0, '<200':1, '<300':2, '<400':3},inplace = True)
train.replace({'Elevated':0, 'Normal':1, 'Stage-01':2, 'Stage-02':3},inplace = True)


test.replace({'<100':0, '<200':1, '<300':2, '<400':3},inplace = True)
test.replace({'Elevated':0, 'Normal':1, 'Stage-01':2, 'Stage-02':3},inplace = True)

# %%
train.head()
# Out:
#    people_ID        Region Designation             Name Children  cases/1M  \
# 0          1  Bhubaneshwar         Mrs            mansi        1         2
# 1          2  Bhubaneshwar         Mrs        riya masi        2         2
# 2          3  Bhubaneshwar         Mrs           sunita        1         2
# 3          4  Bhubaneshwar         Mrs   anjali @ babli        1         2
# 4          5  Bhubaneshwar         Mrs  champa karketta        2         2
#
#    Deaths/1M  Age  Coma score  Pulmonary score  ...  Infect_Prob  \
# 0          0   68           8                3  ...    49.135010
# 1          0   64          15                0  ...    51.147880
# 2          0   19          13                2  ...    73.224000
# 3          0   33           9                1  ...    48.779225
# 4          0   23           7                3  ...    87.868800
#
#   Coronary Heart Disease Diabetes Hypertension Car Public Walk  Married_n  \
# ...

# %%
test.head()
# Out:
#    people_ID Region Designation                Name  Children  cases/1M  \
# 0       5942  Delhi         Mrs  smt rekha prajapat         2         4
# 1      18664  Delhi          Mr              nirmal         2         4
# 2       5603  Delhi         Mrs               pinky         2         4
# 3       5649  Delhi         Mrs       pooja @aafrin         2         4
# 4       5099  Delhi         Mrs              anjali         2         4
#
#    Deaths/1M  Age  Coma score  Pulmonary score  ...  FT/month  \
# 0          1   52           3                1  ...         1
# 1          1   53          11                1  ...         1
# 2          1   35           9                0  ...         2
# 3          1   31          12                2  ...         2
# 4          1   51           6                1  ...         1
#
#    Coronary Heart Disease  Diabetes  Hypertension  Car  Public  Walk  \
# 0                       0         1             0    0       1     0
# ...

# %%
import matplotlib as pl
# %matplotlib inline

# %%
train = train.drop(['people_ID','Name','Designation'], axis = 1)

# %%
train.head()
# Out:
#          Region Children  cases/1M  Deaths/1M  Age  Coma score  \
# 0  Bhubaneshwar        1         2          0   68           8
# 1  Bhubaneshwar        2         2          0   64          15
# 2  Bhubaneshwar        1         2          0   19          13
# 3  Bhubaneshwar        1         2          0   33           9
# 4  Bhubaneshwar        2         2          0   23           7
#
#    Pulmonary score  cardiological pressure Diuresis Platelets  ...  \
# 0                3                       1      441       154  ...
# 1                0                       3    276.0       121  ...
# 2                2                       0      416       124  ...
# 3                1                       2      410        98  ...
# 4                3                       1      390        21  ...
#
#   Infect_Prob Coronary Heart Disease Diabetes Hypertension  Car  Public  Walk  \
# 0   49.135010                      0        0            1    0       1     0
# ...

# %%
ax = sns.barplot(x = 'Children', y = 'Infect_Prob', data = train)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# Out:
# [Text(0, 0, '1.0'), Text(0, 0, '2.0'), Text(0, 0, '0.0'), Text(0, 0, '2.0')]

# %%
plt.scatter(train.Children,train['Infect_Prob'])

# %%
ax = sns.barplot(x = 'Pulmonary score', y = 'Infect_Prob', data = train)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# Out:
# [Text(0, 0, '0'), Text(0, 0, '1'), Text(0, 0, '2'), Text(0, 0, '3')]

# %%
ax = sns.barplot(x = 'cardiological pressure', y = 'Infect_Prob', data = train)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# Out:
# [Text(0, 0, '0'), Text(0, 0, '1'), Text(0, 0, '2'), Text(0, 0, '3')]

# %%
ax = sns.barplot(x = 'Married_n', y = 'Infect_Prob', data = train)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# Out:
# [Text(0, 0, '0'), Text(0, 0, '1')]

# %%
ax = sns.barplot(x = 'Gender_n', y = 'Infect_Prob', data = train)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# Out:
# [Text(0, 0, '0'), Text(0, 0, '1')]

# %%
ax = sns.barplot(x = 'Occupation_n', y = 'Infect_Prob', data = train)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8')]

# %%
ax = sns.barplot(x = 'Blood Glucose', y = 'Infect_Prob', data = train)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# Out:
# [Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7')]

# %%
corrmatrix = train.corr()

# %%
plt.subplots(figsize = (20,15))
sns.heatmap(corrmatrix,annot = True, linewidths = .5)

# %%
train_x = train.drop(['Infect_Prob','Region'],axis = 1)
train_x.head()
# Out:
#   Children  cases/1M  Deaths/1M  Age  Coma score  Pulmonary score  \
# 0        1         2          0   68           8                3
# 1        2         2          0   64          15                0
# 2        1         2          0   19          13                2
# 3        1         2          0   33           9                1
# 4        2         2          0   23           7                3
#
#    cardiological pressure Diuresis Platelets  HBB  ... FT/month  \
# 0                       1      441       154   93  ...        2
# 1                       3    276.0       121   56  ...        1
# 2                       0      416       124  137  ...        1
# 3                       2      410        98  167  ...        1
# 4                       1      390        21  153  ...        1
#
#   Coronary Heart Disease Diabetes  Hypertension  Car  Public  Walk Married_n  \
# 0                      0        0             1    0       1     0         1
# ...

# %%
train_y = train.Infect_Prob
train_y.head()
# Out:
# 0    49.135010
# 1    51.147880
# 2    73.224000
# 3    48.779225
# 4    87.868800
# Name: Infect_Prob, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train_x,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
test = test.drop(['people_ID','Name','Designation','Region'], axis = 1)

# %%
test.head()
# Out:
#    Children  cases/1M  Deaths/1M  Age  Coma score  Pulmonary score  \
# 0         2         4          1   52           3                1
# 1         2         4          1   53          11                1
# 2         2         4          1   35           9                0
# 3         2         4          1   31          12                2
# 4         2         4          1   51           6                1
#
#    cardiological pressure  Diuresis  Platelets  HBB  ...  FT/month  \
# 0                       2       388        153  196  ...         1
# 1                       2       409         95  138  ...         1
# 2                       3       440         40  166  ...         2
# 3                       0       206         78   83  ...         2
# 4                       2       229        109  207  ...         1
#
#    Coronary Heart Disease  Diabetes  Hypertension  Car  Public  Walk  \
# 0                       0         1             0    0       1     0
# ...

# %%
model.score(train_x,train_y)
# Out:
# 0.2865555285589667

# %%
test_y = model.predict(test)

# %%
test_y[12]
# Out:
# 52.33985292841499

# %%
from sklearn.tree import DecisionTreeRegressor
clf = DecisionTreeRegressor(max_depth =10)

clf.fit(train_x,train_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=10, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
dtypes=train_x.dtypes
print(dtypes)
# Out:
# Children                   object
# cases/1M                    int64
# Deaths/1M                   int64
# Age                         int64
# Coma score                  int64
# Pulmonary score             int64
# cardiological pressure      int64
# Diuresis                   object
# Platelets                  object
# HBB                        object
# d-dimer                    object
# Heart rate                 object
# HDL cholesterol            object
# Charlson Index              int64
# Blood Glucose               int64
# Insurance                 float64
# salary                    float64
# FT/month                   object
# Coronary Heart Disease      uint8
# Diabetes                    uint8
# Hypertension                uint8
# Car                         uint8
# Public                      uint8
# Walk                        uint8
# Married_n                   int32
# Occupation_n                int32
# Gender_n                    int32
# dtype: object

# %%
clf.predict(test)
# Out:
# array([52.75668033, 53.06332733, 51.5712693 , ..., 45.01905372,
#        45.39699725, 45.636974  ])

# %%
clf.score(train_x,train_y)
# Out:
# 0.6430197177442438
